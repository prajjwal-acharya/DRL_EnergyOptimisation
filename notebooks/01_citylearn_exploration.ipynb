# %% [markdown]
# # CityLearn environment exploration
#
# This notebook is for reviewing Day 2 inspection evidence. It does not train or evaluate an agent.

# %%
from pathlib import Path
import json

inspection_path = Path('../outputs/environment-inspection/citylearn_2023_phase_1.json')
inspection = json.loads(inspection_path.read_text())
inspection
